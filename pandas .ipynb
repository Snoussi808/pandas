# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# TASK 1
df = pd.read_csv("C:/Users/snoussi/Desktop/course/Online Shopping Dataset.csv")

# %%
df
# Out:
#        CustomerID Gender Location  Tenure_Months  Transaction_ID  \
# 0         17850.0      M  Chicago           12.0         16679.0
# 1         17850.0      M  Chicago           12.0         16680.0
# 2         17850.0      M  Chicago           12.0         16696.0
# 3         17850.0      M  Chicago           12.0         16699.0
# 4         17850.0      M  Chicago           12.0         16700.0
# ...           ...    ...      ...            ...             ...
# 52950         NaN    NaN      NaN            NaN             NaN
# 52951         NaN    NaN      NaN            NaN             NaN
# 52952         NaN    NaN      NaN            NaN             NaN
# 52953         NaN    NaN      NaN            NaN             NaN
# 52954         NaN    NaN      NaN            NaN             NaN
#
#       Transaction_Date     Product_SKU  \
# 0             1/1/2019  GGOENEBJ079499
# 1             1/1/2019  GGOENEBJ079499
# 2             1/1/2019  GGOENEBQ078999
# ...

# %%
df.head()
# Out:
#    CustomerID Gender Location  Tenure_Months  Transaction_ID Transaction_Date  \
# 0     17850.0      M  Chicago           12.0         16679.0         1/1/2019
# 1     17850.0      M  Chicago           12.0         16680.0         1/1/2019
# 2     17850.0      M  Chicago           12.0         16696.0         1/1/2019
# 3     17850.0      M  Chicago           12.0         16699.0         1/1/2019
# 4     17850.0      M  Chicago           12.0         16700.0         1/1/2019
#
#       Product_SKU                                Product_Description  \
# 0  GGOENEBJ079499  Nest Learning Thermostat 3rd Gen-USA - Stainle...
# 1  GGOENEBJ079499  Nest Learning Thermostat 3rd Gen-USA - Stainle...
# 2  GGOENEBQ078999             Nest Cam Outdoor Security Camera - USA
# 3  GGOENEBQ079099    Nest Protect Smoke + CO White Battery Alarm-USA
# 4  GGOENEBJ079499  Nest Learning Thermostat 3rd Gen-USA - Stainle...
#
#   Product_Category  Quantity  Avg_Price  Delivery_Charges Coupon_Status  GST  \
# ...

# %%
df.dtypes
# Out:
# CustomerID             float64
# Gender                  object
# Location                object
# Tenure_Months          float64
# Transaction_ID         float64
# Transaction_Date        object
# Product_SKU             object
# Product_Description     object
# Product_Category        object
# Quantity               float64
# Avg_Price              float64
# Delivery_Charges       float64
# Coupon_Status           object
# GST                    float64
# Date                    object
# Offline_Spend          float64
# Online_Spend           float64
# Month                    int64
# Coupon_Code             object
# Discount_pct           float64
# dtype: object

# %%
df.mean
# Out:
# <bound method DataFrame.mean of        CustomerID Gender Location  Tenure_Months  Transaction_ID  \
# 0         17850.0      M  Chicago           12.0         16679.0
# 1         17850.0      M  Chicago           12.0         16680.0
# 2         17850.0      M  Chicago           12.0         16696.0
# 3         17850.0      M  Chicago           12.0         16699.0
# 4         17850.0      M  Chicago           12.0         16700.0
# ...           ...    ...      ...            ...             ...
# 52950         NaN    NaN      NaN            NaN             NaN
# 52951         NaN    NaN      NaN            NaN             NaN
# 52952         NaN    NaN      NaN            NaN             NaN
# 52953         NaN    NaN      NaN            NaN             NaN
# 52954         NaN    NaN      NaN            NaN             NaN
#
#       Transaction_Date     Product_SKU  \
# 0             1/1/2019  GGOENEBJ079499
# 1             1/1/2019  GGOENEBJ079499
# ...

# %%
df.median
# Out:
# <bound method DataFrame.median of        CustomerID Gender Location  Tenure_Months  Transaction_ID  \
# 0         17850.0      M  Chicago           12.0         16679.0
# 1         17850.0      M  Chicago           12.0         16680.0
# 2         17850.0      M  Chicago           12.0         16696.0
# 3         17850.0      M  Chicago           12.0         16699.0
# 4         17850.0      M  Chicago           12.0         16700.0
# ...           ...    ...      ...            ...             ...
# 52950         NaN    NaN      NaN            NaN             NaN
# 52951         NaN    NaN      NaN            NaN             NaN
# 52952         NaN    NaN      NaN            NaN             NaN
# 52953         NaN    NaN      NaN            NaN             NaN
# 52954         NaN    NaN      NaN            NaN             NaN
#
#       Transaction_Date     Product_SKU  \
# 0             1/1/2019  GGOENEBJ079499
# 1             1/1/2019  GGOENEBJ079499
# ...

# %%
df.sum
# Out:
# <bound method DataFrame.sum of        CustomerID Gender Location  Tenure_Months  Transaction_ID  \
# 0         17850.0      M  Chicago           12.0         16679.0
# 1         17850.0      M  Chicago           12.0         16680.0
# 2         17850.0      M  Chicago           12.0         16696.0
# 3         17850.0      M  Chicago           12.0         16699.0
# 4         17850.0      M  Chicago           12.0         16700.0
# ...           ...    ...      ...            ...             ...
# 52950         NaN    NaN      NaN            NaN             NaN
# 52951         NaN    NaN      NaN            NaN             NaN
# 52952         NaN    NaN      NaN            NaN             NaN
# 52953         NaN    NaN      NaN            NaN             NaN
# 52954         NaN    NaN      NaN            NaN             NaN
#
#       Transaction_Date     Product_SKU  \
# 0             1/1/2019  GGOENEBJ079499
# 1             1/1/2019  GGOENEBJ079499
# ...

# %%
df.max
# Out:
# <bound method DataFrame.max of        CustomerID Gender Location  Tenure_Months  Transaction_ID  \
# 0         17850.0      M  Chicago           12.0         16679.0
# 1         17850.0      M  Chicago           12.0         16680.0
# 2         17850.0      M  Chicago           12.0         16696.0
# 3         17850.0      M  Chicago           12.0         16699.0
# 4         17850.0      M  Chicago           12.0         16700.0
# ...           ...    ...      ...            ...             ...
# 52950         NaN    NaN      NaN            NaN             NaN
# 52951         NaN    NaN      NaN            NaN             NaN
# 52952         NaN    NaN      NaN            NaN             NaN
# 52953         NaN    NaN      NaN            NaN             NaN
# 52954         NaN    NaN      NaN            NaN             NaN
#
#       Transaction_Date     Product_SKU  \
# 0             1/1/2019  GGOENEBJ079499
# 1             1/1/2019  GGOENEBJ079499
# ...

# %%
df.min
# Out:
# <bound method DataFrame.min of        CustomerID Gender Location  Tenure_Months  Transaction_ID  \
# 0         17850.0      M  Chicago           12.0         16679.0
# 1         17850.0      M  Chicago           12.0         16680.0
# 2         17850.0      M  Chicago           12.0         16696.0
# 3         17850.0      M  Chicago           12.0         16699.0
# 4         17850.0      M  Chicago           12.0         16700.0
# ...           ...    ...      ...            ...             ...
# 52950         NaN    NaN      NaN            NaN             NaN
# 52951         NaN    NaN      NaN            NaN             NaN
# 52952         NaN    NaN      NaN            NaN             NaN
# 52953         NaN    NaN      NaN            NaN             NaN
# 52954         NaN    NaN      NaN            NaN             NaN
#
#       Transaction_Date     Product_SKU  \
# 0             1/1/2019  GGOENEBJ079499
# 1             1/1/2019  GGOENEBJ079499
# ...

# %%
#task2
df['Total'] = df['Online_Spend'] + df['Offline_Spend']
df
# Out:
#        CustomerID Gender Location  Tenure_Months  Transaction_ID  \
# 0         17850.0      M  Chicago           12.0         16679.0
# 1         17850.0      M  Chicago           12.0         16680.0
# 2         17850.0      M  Chicago           12.0         16696.0
# 3         17850.0      M  Chicago           12.0         16699.0
# 4         17850.0      M  Chicago           12.0         16700.0
# ...           ...    ...      ...            ...             ...
# 52950         NaN    NaN      NaN            NaN             NaN
# 52951         NaN    NaN      NaN            NaN             NaN
# 52952         NaN    NaN      NaN            NaN             NaN
# 52953         NaN    NaN      NaN            NaN             NaN
# 52954         NaN    NaN      NaN            NaN             NaN
#
#       Transaction_Date     Product_SKU  \
# 0             1/1/2019  GGOENEBJ079499
# 1             1/1/2019  GGOENEBJ079499
# 2             1/1/2019  GGOENEBQ078999
# ...

# %%
df.loc[df['Avg_Price'] > 120]
# Out:
#        CustomerID Gender    Location  Tenure_Months  Transaction_ID  \
# 0         17850.0      M     Chicago           12.0         16679.0
# 1         17850.0      M     Chicago           12.0         16680.0
# 2         17850.0      M     Chicago           12.0         16696.0
# 4         17850.0      M     Chicago           12.0         16700.0
# 5         17850.0      M     Chicago           12.0         16701.0
# ...           ...    ...         ...            ...             ...
# 52739     14224.0      F     Chicago            3.0         40225.0
# 52740     14224.0      F     Chicago            3.0         40233.0
# 52862     12748.0      F     Chicago           28.0         26585.0
# 52863     12748.0      F     Chicago           28.0         26586.0
# 52919     13155.0      F  California            8.0         22504.0
#
#       Transaction_Date     Product_SKU  \
# 0             1/1/2019  GGOENEBJ079499
# 1             1/1/2019  GGOENEBJ079499
# ...

# %%
df.sort_values(['Avg_Price'], ascending = True)
# Out:
#        CustomerID Gender    Location  Tenure_Months  Transaction_ID  \
# 5883      12836.0      M     Chicago            6.0         45818.0
# 28623     17180.0      F     Chicago           35.0         43558.0
# 49371     13168.0      F     Chicago           24.0         41774.0
# 28399     12826.0      M  California           33.0         42923.0
# 28389     13707.0      F     Chicago           28.0         43949.0
# ...           ...    ...         ...            ...             ...
# 52950         NaN    NaN         NaN            NaN             NaN
# 52951         NaN    NaN         NaN            NaN             NaN
# 52952         NaN    NaN         NaN            NaN             NaN
# 52953         NaN    NaN         NaN            NaN             NaN
# 52954         NaN    NaN         NaN            NaN             NaN
#
#       Transaction_Date     Product_SKU    Product_Description  \
# 5883         12/6/2019  GGOEYFKQ020699  YouTube Custom Decals
# ...

# %%
#task
df['Online_Spend'].mean()
# Out:
# 1893.1091191142013

# %%
df['Location'].mode()
# Out:
# 0    Chicago
# Name: Location, dtype: object

# %%
gmean = df[['Online_Spend','Gender']].groupby('Gender').mean()
gmean
# Out:
#         Online_Spend
# Gender
# F        1899.806601
# M        1882.009868

# %%
#task4
plt.hist(df['Online_Spend'], bins=20, edgecolor='black')

plt.title('online spend')
plt.xlabel('$')
plt.ylabel('Frequency')

plt.show()

# %%
category_counts = df['Offline_Spend'].value_counts()
category_counts.plot(kind='bar', color='skyblue', edgecolor='black')
plt.title('offline spend')
plt.xlabel('$')
plt.ylabel('Frequency')
plt.show()

# %%
#task5
df.isnull().sum()
# Out:
# CustomerID              31
# Gender                  31
# Location                31
# Tenure_Months           31
# Transaction_ID          31
# Transaction_Date        31
# Product_SKU             31
# Product_Description     31
# Product_Category         0
# Quantity                31
# Avg_Price               31
# Delivery_Charges        31
# Coupon_Status           31
# GST                     31
# Date                    31
# Offline_Spend           31
# Online_Spend            31
# Month                    0
# Coupon_Code            400
# Discount_pct           400
# dtype: int64

# %%
df1 = pd.DataFrame({
    'CustomerID': [1, 2, 3],
    'Name': ['John', 'Jane', 'Doe'],
    'Age': [28, 34, 29]
})

df2 = pd.DataFrame({
    'CustomerID': [1, 2, 4],
    'City': ['New York', 'Los Angeles', 'Chicago'],
    'Spending_Score': [50, 80, 60]
})
merged_df = pd.merge(df1, df2, on='CustomerID', how='inner')

# %%
merged_df
# Out:
#    CustomerID  Name  Age         City  Spending_Score
# 0           1  John   28     New York              50
# 1           2  Jane   34  Los Angeles              80
